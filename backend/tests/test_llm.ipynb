# %%
import sys
sys.path.append('..')
email_content = {
        "Subject": "转发：关于东华大学钓鱼邮件演练的说明—信息化办公室",
        "From": "刘思敏, <220120114@mail.dhu.edu.cn>",
        "Date": "Tue, 5 Nov 2024 05:37:58 +0800 (GMT+08:00)",
        "Content": """
          220120114@mail.dhu.edu.cn\n 邮箱：220120114@mail.dhu.edu.cn\n
              \n\n\n\n---- 转发的邮件 ----\n发件人  admin<admin@mail.dhu.edu.cn> 日期  2024年03月26日 11:03 收件人  220120114@mail.dhu.edu.cn 抄送至  
              主题  关于东华大学钓鱼邮件演练的说明—信息化办公室  \n\n关
              于东华大学钓鱼邮件演练的说明\n
              同学：您好！\n我们不幸地通知您：\n由于您在本次学校开展的钓鱼邮件演练中，未能第一时间准确的识别出钓鱼邮件，因此收到了该邮件。演练过程中，不会记录学生的账号密码，此邮件目的旨在警醒各位同学。
              \n近年来，钓鱼邮件异常活跃，不法组织利用系统密码过期、系统升级、培训升职、各种优惠等“吸引眼球”的热门内容来吸引用户点击非法链接，窃取学校用户账号密码及重要数据，具有极强的隐蔽性、持续性和危害性。
              \n为持续提升广大师生的网络安全意识，今后我校将会不定期开展钓鱼邮件演练。
              \n \n信息化办公x室\n2024年3月26日\n如何识别钓鱼邮件及钓鱼网站\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n\r\n 220120114@mail.dhu.edu.cn 邮箱：220120114@mail.dhu.edu.cn ---- 转发的邮件 ---- 发件人 adminadmin@mail.dhu.edu.cn 日期 2024年03月26日 11:03 收件人 220120114@mail.dhu.edu.cn 抄送至 主题 关于东华大学钓鱼邮件演练的说明—信息化办公室 关于东华大学钓鱼邮件演练的说明同学：您好！我们不幸地通知您：由于您在本次学校开展的钓鱼邮件演练中，未能第一时间准确的识别出钓鱼邮件，因此收到了该邮件。演练过程中，不会记录学生的账号密码，此邮件目的旨在警醒各位同学。近年来，钓鱼邮件异常活跃，不法组织利用系统密码过期、系统升级、培训升职、各种优惠等“吸引眼球”的热门内容来吸引用户点击非法链接，窃取学校用户账号密码及重要数据，具有极强的隐蔽性、持续性和危害性。为持续提升广大师生的网络安全意识，今后我校将会不定期开展钓鱼邮件演练。信息化办公室2024年3月26日如何识别钓鱼邮件及钓鱼网站
              """
}

# %%
import sys
sys.path.append("..")
from utils.llm import LLM

llm = LLM()
while True:
    # print(llm.summary(email_content))
    # print(llm.classify(email_content))
    print(llm.ask(email_content, "他让我干啥？"))
# Out:
# 根据邮件内容，这封邮件是学校信息化办公室发出的关于钓鱼邮件演练的通知。它不是真正的钓鱼邮件，而是一次演练的通知。邮件中提到，你在学校开展的钓鱼邮件演练中未能第一时间准确识别出钓鱼邮件，因此收到了该邮件。邮件的目的在于警醒你和其他同学提高网络安全意识。
# 根据邮件内容，似乎是学校信息化办公室组织的一次钓鱼邮件演练。您收到了这个邮件，说明您在演练中未能第一时间准确识别出钓鱼邮件。演练的目的是为了警醒师生提高网络安全意识。您不需要采取任何行动，演练过程中不会记录您的账号密码。
# 你收到了学校组织的钓鱼邮件演练。演练的目的是为了警醒你识别钓鱼邮件的重要性。演练过程中不会记录你的账号密码，目的在于提高你的网络安全意识。
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 llm = LLM()
#       6 while True:
#       7     # print(llm.summary(email_content))
#       8     # print(llm.classify(email_content))
# ----> 9     print(llm.ask(email_content, "他让我干啥？"))
#
# File ~/Documents/se软件工程导论/backend/tests/../utils/llm.py:81, in LLM.ask(self, email, question)
#      80 def ask(self, email: dict,question:str) -> str:
# ---> 81     return self.query(LLM.prompt_ask, email, question)
#
# ...

# %%
llm.classify(email_content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 llm.classify(email_content)
#
# File ~/Documents/se软件工程导论/backend/tests/../utils/llm.py:58, in LLM.classify(self, email)
#      57 def classify(self,email:dict) -> str:
# ---> 58     return self.query(LLM.prompt_classify ,email)
#
# File ~/Documents/se软件工程导论/backend/tests/../utils/llm.py:55, in LLM.query(self, query, email)
#      53     return response.json()['choices'][0]['message']['content']
#      54 else:
# ---> 55     raise ConnectionError(f"Failed to query LLM, status code : {response.status_code}, msg: {response.text}")
#
# ConnectionError: Failed to query LLM, status code : 429, msg: {"message":"Request was rejected due to rate limiting. If you want more, please contact contact@siliconflow.cn. Details: TPM limit reached.","data":null}
